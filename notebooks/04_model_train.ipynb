# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from src.deep_learning.preprocessing import scale_df, TimeSeriesDataset
from src.deep_learning.lstm_model import LSTMModel
from src.deep_learning.training import  evaluate_model, train_model
import joblib

# %%
random_seed = 42
np.random.seed(random_seed)
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
train_df = pd.read_parquet(r"..\data\processed\train.parquet")
val_df = pd.read_parquet(r"..\data\processed\val.parquet")
test_df = pd.read_parquet(r"..\data\processed\test.parquet")
consumption_df = pd.read_parquet(r"..\data\processed\consumption_fe.parquet")

# %%
train_df.head()
# Out:
#                  date  consumption  hour_sin  hour_cos  day_sin  day_cos  \
# 0 2018-01-01 00:00:00     27412.81  0.000000  1.000000      0.0      1.0
# 1 2018-01-01 01:00:00     26324.39  0.258819  0.965926      0.0      1.0
# 2 2018-01-01 02:00:00     24635.32  0.500000  0.866025      0.0      1.0
# 3 2018-01-01 03:00:00     23872.12  0.707107  0.707107      0.0      1.0
# 4 2018-01-01 04:00:00     23194.89  0.866025  0.500000      0.0      1.0
#
#    month_sin  month_cos
# 0        0.5   0.866025
# 1        0.5   0.866025
# 2        0.5   0.866025
# 3        0.5   0.866025
# 4        0.5   0.866025

# %%
feature_cols = ["consumption",
    "hour_sin", "hour_cos",
    "day_sin", "day_cos",
    "month_sin", "month_cos"
]

target = "consumption"

scale_cols = ["consumption"]

# %%
scaler = StandardScaler()

scaler_path = r"..\models\scaler.pkl"

train_scaled = scale_df(df=train_df, train=True, scaler=scaler, scale_cols=scale_cols)

joblib.dump(scaler, scaler_path)

val_scaled = scale_df(df=val_df, train=False, scaler=scaler, scale_cols=scale_cols)

test_scaled = scale_df(df=test_df, train=False, scaler=scaler, scale_cols=scale_cols)

# %%
train_scaled.head(2)
# Out:
#                  date  consumption  hour_sin  hour_cos  day_sin  day_cos  \
# 0 2018-01-01 00:00:00    -1.350096  0.000000  1.000000      0.0      1.0
# 1 2018-01-01 01:00:00    -1.539594  0.258819  0.965926      0.0      1.0
#
#    month_sin  month_cos
# 0        0.5   0.866025
# 1        0.5   0.866025

# %%
window_size = 168
horizon = 24

hidden_size = 256
num_layers = 2
lin_features = 64
dropout = 0.3

lr= 0.0005
num_epochs = 50
min_delta = 0.0001
patience = 7
scheduler_patience = 3
weight_decay = 5e-5

# %%
train_dataset = TimeSeriesDataset(df=train_scaled, feature_cols=feature_cols, target_col=target, window_size=window_size, horizon=horizon) 
val_dataset = TimeSeriesDataset(df=val_scaled, feature_cols=feature_cols, target_col=target, window_size=window_size, horizon=horizon) 
test_dataset = TimeSeriesDataset(df=test_scaled, feature_cols=feature_cols, target_col=target, window_size=window_size, horizon=horizon)

# %%
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LSTMModel(input_size=len(feature_cols),
                    hidden_size=hidden_size,
                    num_layers=num_layers,
                    horizon=horizon,
                    lin_features=lin_features,
                    dropout=dropout
                    )
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
criterion = nn.HuberLoss()

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,
                                                            mode="min",
                                                            factor=0.5,
                                                            patience=scheduler_patience,
                                                            threshold=min_delta
                                                            )
model = model.to(device)

# %%
training_dict = {"model": model,
                "device": device,
                "train_loader":train_loader,
                "val_loader":val_loader,
                "criterion": criterion,
                "optimizer":optimizer,
                "lr_scheduler": lr_scheduler,
                "num_epochs": num_epochs,
                "save_path":r"..\models\lstm_model.pth",
                "min_delta":min_delta,
                "patience":patience
                }

# %%
train_total_loss, val_total_loss = train_model(**training_dict)
# Out:
# Epoch [001/050]
# Train Loss: 0.049394 | Validation Loss: 0.039770 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [002/050]
# Train Loss: 0.024280 | Validation Loss: 0.029909 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [003/050]
# Train Loss: 0.021124 | Validation Loss: 0.028967 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [004/050]
# Train Loss: 0.019161 | Validation Loss: 0.027865 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [005/050]
# Train Loss: 0.018009 | Validation Loss: 0.026839 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [006/050]
# Train Loss: 0.017088 | Validation Loss: 0.026149 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [007/050]
# Train Loss: 0.016267 | Validation Loss: 0.023482 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [008/050]
# Train Loss: 0.015376 | Validation Loss: 0.024043 | Learning Rate: 0.0005
# --> No improvement. EarlyStopping counter: 1/7
# Epoch [009/050]
# Train Loss: 0.015049 | Validation Loss: 0.022369 | Learning Rate: 0.0005
# --> Validation loss improved. Saving model...
# Epoch [010/050]
# Train Loss: 0.014623 | Validation Loss: 0.023492 | Learning Rate: 0.0005
# --> No improvement. EarlyStopping counter: 1/7
# Epoch [011/050]
# Train Loss: 0.013949 | Validation Loss: 0.022447 | Learning Rate: 0.0005
# --> No improvement. EarlyStopping counter: 2/7
# Epoch [012/050]
# Train Loss: 0.014361 | Validation Loss: 0.024576 | Learning Rate: 0.0005
# --> No improvement. EarlyStopping counter: 3/7
# Epoch [013/050]
# Train Loss: 0.013299 | Validation Loss: 0.022659 | Learning Rate: 0.00025
# --> No improvement. EarlyStopping counter: 4/7
# Epoch [014/050]
# Train Loss: 0.011307 | Validation Loss: 0.022873 | Learning Rate: 0.00025
# --> No improvement. EarlyStopping counter: 5/7
# Epoch [015/050]
# Train Loss: 0.011104 | Validation Loss: 0.022542 | Learning Rate: 0.00025
# --> No improvement. EarlyStopping counter: 6/7
# Epoch [016/050]
# Train Loss: 0.011032 | Validation Loss: 0.020773 | Learning Rate: 0.00025
# --> Validation loss improved. Saving model...
# Epoch [017/050]
# Train Loss: 0.010792 | Validation Loss: 0.020458 | Learning Rate: 0.00025
# --> Validation loss improved. Saving model...
# Epoch [018/050]
# Train Loss: 0.010433 | Validation Loss: 0.023217 | Learning Rate: 0.00025
# --> No improvement. EarlyStopping counter: 1/7
# Epoch [019/050]
# Train Loss: 0.010232 | Validation Loss: 0.023104 | Learning Rate: 0.00025
# --> No improvement. EarlyStopping counter: 2/7
# Epoch [020/050]
# Train Loss: 0.010088 | Validation Loss: 0.022200 | Learning Rate: 0.00025
# --> No improvement. EarlyStopping counter: 3/7
# Epoch [021/050]
# Train Loss: 0.010521 | Validation Loss: 0.022489 | Learning Rate: 0.000125
# --> No improvement. EarlyStopping counter: 4/7
# Epoch [022/050]
# Train Loss: 0.008770 | Validation Loss: 0.022155 | Learning Rate: 0.000125
# --> No improvement. EarlyStopping counter: 5/7
# Epoch [023/050]
# Train Loss: 0.008695 | Validation Loss: 0.022014 | Learning Rate: 0.000125
# --> No improvement. EarlyStopping counter: 6/7
# Epoch [024/050]
# Train Loss: 0.008606 | Validation Loss: 0.021514 | Learning Rate: 0.000125
# --> No improvement. EarlyStopping counter: 7/7
# Early stopping triggered at epoch 24. Training stopped.

# %%
plt.figure(figsize=(10,6))
plt.plot(train_total_loss, label="train_loss")
plt.plot(val_total_loss, label="val_loss")
plt.legend()
plt.tight_layout()
plt.show()

# %%
model_path = training_dict["save_path"]
model.load_state_dict(torch.load(model_path, map_location=device))
test_loss, test_preds, test_targets = evaluate_model(model=model, 
                                                        device=device,
                                                        dataloader=test_loader,
                                                        criterion=criterion)

test_preds = torch.cat(test_preds, dim=0)
test_targets = torch.cat(test_targets, dim=0)

# %%
test_preds.shape
# Out:
# torch.Size([8569, 24])

# %%
test_targets_np = test_targets.cpu().numpy()
test_preds_np = test_preds.cpu().numpy()

test_targets_inv = scaler.inverse_transform(test_targets_np.reshape(-1, 1)).reshape(test_targets_np.shape)
test_preds_inv = scaler.inverse_transform(test_preds_np.reshape(-1, 1)).reshape(test_preds_np.shape)

rmse = np.sqrt(mean_squared_error(test_targets_inv, test_preds_inv))
mae = mean_absolute_error(test_targets_inv, test_preds_inv)
mape = mean_absolute_percentage_error(test_targets_inv, test_preds_inv) * 100
r2 = r2_score(test_targets_inv, test_preds_inv)

print(f"Test Loss: {test_loss:.6f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.2f}%")
print(f"R2: {r2:.4f}")
# Out:
# Test Loss: 0.032871
# RMSE: 1477.9811
# MAE:  1006.0803
# MAPE: 2.47%
# R2: 0.9497

# %%
sample_idx = 25

plt.figure(figsize=(10, 5))
plt.plot(test_targets_inv[:sample_idx, 0], label="Real")
plt.plot(test_preds_inv[:sample_idx, 0], label="Prediction")
plt.title("24-hour Forecast vs Real")
plt.xlabel("Forecast Horizon (hours)")
plt.ylabel("Consumption")
plt.legend()
plt.show()

# %%
real_series = test_targets_inv[:168*3, 0]
pred_series = test_preds_inv[:168*3, 0]

plt.figure(figsize=(14, 6))
plt.plot(real_series, label="Real", alpha=0.8)
plt.plot(pred_series, label="Prediction", alpha=0.8)
plt.title("Forecast on Test Set")
plt.xlabel("Time Index")
plt.ylabel("Consumption")
plt.legend()
plt.show()

# %%
real_series = test_targets_inv[168*24:168*30, 0]
pred_series = test_preds_inv[168*24:168*30, 0]

plt.figure(figsize=(14, 6))
plt.plot(real_series, label="Real", alpha=0.8)
plt.plot(pred_series, label="Prediction", alpha=0.8)
plt.title("Forecast on Test Set")
plt.xlabel("Time Index")
plt.ylabel("Consumption")
plt.legend()
plt.show()

# %%
real_series = test_targets_inv[:, 0]
pred_series = test_preds_inv[:, 0]

plt.figure(figsize=(14, 6))
plt.plot(real_series, label="Real", alpha=1)
plt.plot(pred_series, label="Prediction", alpha=0.9)
plt.title("Forecast on Test Set")
plt.xlabel("Time Index")
plt.ylabel("Consumption")
plt.legend()
plt.show()
